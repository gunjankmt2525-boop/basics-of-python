# %% [markdown]
# Name: Gunjan Kumawat<br>
# Roll no:250243<br>
# Course:BCA<br>
# Topic: Armstrong,palindrome and reverse number

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gunjankmt2525-boop/basics-of-python/blob/main/numbers.ipynb)

# %% [markdown]
# Armstrong number

# %%
num = int(input("Enter a number: "))

temp = num
sum = 0

while temp > 0:
    digit = temp % 10
    sum = sum + digit**3
    temp = temp // 10

if sum == num:
    print("Armstrong number")
else:
    print("Not an Armstrong number")
# Out:
# Enter a number: 3
# Not an Armstrong number

# %% [markdown]
# Palindrome number

# %%
num = int(input("Enter a number: "))

temp = num
reverse = 0

while temp > 0:
    digit = temp % 10
    reverse = reverse * 10 + digit
    temp = temp // 10

if num == reverse:
    print("Palindrome number")
else:
    print("Not a palindrome number")
# Out:
# Enter a number: 4
# Palindrome number

# %% [markdown]
# Reverse number

# %%
num = int(input("Enter a number: "))

reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

print("Reverse number is:", reverse)
# Out:
# Enter a number: 345
# Reverse number is: 543
