# %% [markdown]
# Name: Gunjan kumawat<br>
# Roll no: 25243<br>
# Course: BCA<br>
# Topic: basics of python

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gunjankmt2525/bascis-of-python/blob/main/basics.ipynb)

# %%
print("hello world!")
# Out:
# hello world!

# %%
a = 5
b = 3
sum = a + b
print("Sum is:", sum)
# Out:
# Sum is: 8

# %%
a="gunjan"
b=" kumawat"
c=a+b
print(c)
# Out:
# gunjan kumawat

# %%
a=int(input("enter value of a"))
b=int(input("enter value of b"))
print(a+b)
# Out:
# enter value of a12
# enter value of b12
# 24

# %%
a=input("enter value ofa")
print(a)
# Out:
# enter value ofa1
# 1

# %%
a="gunjan"
len(a)
# Out:
# 6

# %%
a= str(12345678)
len(a)
a[2:4]
# Out:
# '34'

# %%
a=5
b=str(a)
c=int(b)
print(a,"\n",b,"\n",c,"\n")
# Out:
# 5
#  5
#  5

# %%
a=int(input("enter a="))
b=int(input("enter b="))
c=a+b
d=a-b
e=a*b
f=a/b
g=a**b
print("addition=",c)
print("subtraction=",d)
print("multiply=",e)
print("division=", f)
print("exp",g)
# Out:
# enter a=1
# enter b=2
# addition= 3
# subtraction= -1
# multiply= 2
# division= 0.5
# exp 1
